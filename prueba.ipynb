# %%
from analisis_componentes_principales import reducir_dimensionalidad_dataset


reducir_dimensionalidad_dataset()
# Out:
# [pca] >Processing dataframe..
# [pca] >Normalizing input data per feature (zero mean and unit variance)..
# [pca] >The PCA reduction is performed on the [67] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[11]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]
# [pca] >Processing dataframe..
# [pca] >Normalizing input data per feature (zero mean and unit variance)..
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[11]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]
#      jugador_id   posicion        PC1  ...       PC9      PC10      PC11
# 0             1    Portero  11.497751  ...  0.010013 -0.267159  0.124461
# 1             2    Portero  11.832282  ...  0.247132  0.051337  0.329562
# 2             3   Defensor  -5.667197  ...  1.595996 -0.179422 -0.923196
# 3             4   Defensor  -1.782642  ...  0.762465  0.044153  0.167980
# 4             5   Defensor  -4.295145  ...  1.258283 -0.649120  1.201237
# ..          ...        ...        ...  ...       ...       ...       ...
# 794         795  Delantero  -0.601124  ...  0.401041  1.044945 -0.008969
# 795         796  Delantero   4.532503  ... -0.167519  0.071545 -0.154151
# 796         797  Delantero   0.070015  ... -0.032521 -1.119321 -1.531601
# 797         798  Delantero   2.542480  ... -0.093282  0.494760 -0.678594
# 798         799  Delantero   0.409529  ...  0.774895  0.765809 -0.072565
#
# [799 rows x 13 columns]
